# %%
# !pip install deepface
# Out:
# Requirement already satisfied: deepface in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (0.0.47)
# Requirement already satisfied: opencv-python>=3.4.4 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from deepface) (4.4.0.42)
# Requirement already satisfied: tensorflow>=1.9.0 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from deepface) (2.4.0)
# Requirement already satisfied: mtcnn>=0.1.0 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from deepface) (0.1.0)
# Requirement already satisfied: Pillow>=5.2.0 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from deepface) (7.2.0)
# Requirement already satisfied: gdown>=3.10.1 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from deepface) (3.12.2)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from deepface) (1.19.4)
# Requirement already satisfied: keras>=2.2.0 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from deepface) (2.4.3)
# Requirement already satisfied: Flask>=1.1.2 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from deepface) (1.1.2)
# Requirement already satisfied: pandas>=0.23.4 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from deepface) (1.1.5)
# Requirement already satisfied: tqdm>=4.30.0 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from deepface) (4.48.2)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from Flask>=1.1.2->deepface) (1.0.1)
# Requirement already satisfied: click>=5.1 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from Flask>=1.1.2->deepface) (7.1.2)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from Flask>=1.1.2->deepface) (2.11.2)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from Flask>=1.1.2->deepface) (1.1.0)
# Requirement already satisfied: tqdm>=4.30.0 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from deepface) (4.48.2)
# Requirement already satisfied: requests[socks] in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from gdown>=3.10.1->deepface) (2.24.0)
# WARNING: You are using pip version 20.3.1; however, version 20.3.3 is available.
# You should consider upgrading via the 'c:\users\lal\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: filelock in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from gdown>=3.10.1->deepface) (3.0.12)
# Requirement already satisfied: six in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from gdown>=3.10.1->deepface) (1.15.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from Jinja2>=2.10.1->Flask>=1.1.2->deepface) (1.1.1)
# Requirement already satisfied: scipy>=0.14 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from keras>=2.2.0->deepface) (1.5.4)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from deepface) (1.19.4)
# Requirement already satisfied: pyyaml in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from keras>=2.2.0->deepface) (5.3.1)
# Requirement already satisfied: h5py in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from keras>=2.2.0->deepface) (2.10.0)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from deepface) (1.19.4)
# Requirement already satisfied: six in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from gdown>=3.10.1->deepface) (1.15.0)
# Requirement already satisfied: keras>=2.2.0 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from deepface) (2.4.3)
# Requirement already satisfied: opencv-python>=3.4.4 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from deepface) (4.4.0.42)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from deepface) (1.19.4)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from deepface) (1.19.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from pandas>=0.23.4->deepface) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from pandas>=0.23.4->deepface) (2020.1)
# Requirement already satisfied: six in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from gdown>=3.10.1->deepface) (1.15.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.25.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (2.9)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.7.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.25.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (2.9)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from deepface) (1.19.4)
# Requirement already satisfied: tensorboard~=2.4 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.4.0)
# Requirement already satisfied: astunparse~=1.6.3 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.6.3)
# Requirement already satisfied: typing-extensions~=3.7.4 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from tensorflow>=1.9.0->deepface) (3.7.4.2)
# Requirement already satisfied: absl-py~=0.10 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.11.0)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from deepface) (1.19.4)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.1.2)
# Requirement already satisfied: wrapt~=1.12.1 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.12.1)
# Requirement already satisfied: six in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from gdown>=3.10.1->deepface) (1.15.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from tensorflow>=1.9.0->deepface) (3.14.0)
# Requirement already satisfied: wheel~=0.35 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.36.2)
# Requirement already satisfied: tensorflow-estimator<2.5.0,>=2.4.0rc0 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.4.0)
# Requirement already satisfied: grpcio~=1.32.0 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.32.0)
# Requirement already satisfied: gast==0.3.3 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.3.3)
# Requirement already satisfied: google-pasta~=0.2 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from tensorflow>=1.9.0->deepface) (3.3.0)
# Requirement already satisfied: h5py in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from keras>=2.2.0->deepface) (2.10.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.12)
# Requirement already satisfied: termcolor~=1.1.0 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.1.0)
# Requirement already satisfied: six in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from gdown>=3.10.1->deepface) (1.15.0)
# Requirement already satisfied: six in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from gdown>=3.10.1->deepface) (1.15.0)
# Requirement already satisfied: wheel~=0.35 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.36.2)
# Requirement already satisfied: six in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from gdown>=3.10.1->deepface) (1.15.0)
# Requirement already satisfied: six in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from gdown>=3.10.1->deepface) (1.15.0)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from deepface) (1.19.4)
# Requirement already satisfied: six in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from gdown>=3.10.1->deepface) (1.15.0)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from deepface) (1.19.4)
# Requirement already satisfied: six in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from gdown>=3.10.1->deepface) (1.15.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from tensorboard~=2.4->tensorflow>=1.9.0->deepface) (0.4.2)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from tensorboard~=2.4->tensorflow>=1.9.0->deepface) (1.24.0)
# Requirement already satisfied: six in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from gdown>=3.10.1->deepface) (1.15.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from tensorflow>=1.9.0->deepface) (3.14.0)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from deepface) (1.19.4)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from tensorboard~=2.4->tensorflow>=1.9.0->deepface) (3.2.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from tensorboard~=2.4->tensorflow>=1.9.0->deepface) (1.7.0)
# Requirement already satisfied: absl-py~=0.10 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.11.0)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from Flask>=1.1.2->deepface) (1.0.1)
# Requirement already satisfied: wheel~=0.35 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.36.2)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from tensorboard~=2.4->tensorflow>=1.9.0->deepface) (49.6.0)
# Requirement already satisfied: grpcio~=1.32.0 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.32.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow>=1.9.0->deepface) (4.6)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow>=1.9.0->deepface) (0.2.8)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from tensorboard~=2.4->tensorflow>=1.9.0->deepface) (49.6.0)
# Requirement already satisfied: six in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from gdown>=3.10.1->deepface) (1.15.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow>=1.9.0->deepface) (4.1.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from tensorboard~=2.4->tensorflow>=1.9.0->deepface) (1.24.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow>=1.9.0->deepface) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow>=1.9.0->deepface) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow>=1.9.0->deepface) (3.1.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\lal\appdata\local\programs\python\python38\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow>=1.9.0->deepface) (0.4.8)

# %%
from deepface import DeepFace

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("happy.jpg")
plt.imshow(img[:,:,::-1])
plt.show()

# %%
 result = DeepFace.analyze(img, actions = ['emotion'])
# Out:
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000154A2E52820> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000154A2E52820> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000154A2E52820> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
print(result)
# Out:
# {'emotion': {'angry': 5.293870878231473e-12, 'disgust': 3.803758700648168e-22, 'fear': 2.2554945785418015e-13, 'happy': 99.99575614929199, 'sad': 1.0524190026395264e-10, 'surprise': 5.93354358702225e-10, 'neutral': 0.00424869213020429}, 'dominant_emotion': 'happy'}
